# %% [markdown]
# <a href="https://colab.research.google.com/github/CapiAlex/Momento3_Producto_1500/blob/main/LimpiezaBoeing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
datos = pd.read_csv('OrdersandDeliveries.csv')

# %%
datos.head(10)
# Out:
#        Country           Customer Name Delivery Year  Engine Model Series  \
# 0  Afghanistan  Ariana Afghan Airlines           1968     PW          727
# 1  Afghanistan  Ariana Afghan Airlines           1970     PW          727
# 2  Afghanistan  Ariana Afghan Airlines           1979     GE        DC-10
# 3  Afghanistan  Ariana Afghan Airlines            NaN     CF      737-700
# 4      Algeria             Air Algerie           1974     PW          727
# 5      Algeria             Air Algerie           1974     PW      737-200
# 6      Algeria             Air Algerie           1975     PW          727
# 7      Algeria             Air Algerie           1975     PW      737-200
# 8      Algeria             Air Algerie           2015     CF      737-800
# 9      Algeria             Air Algerie           2016     CF      737-800
#
#   Order Month Order Year        Region Delivery Total Order Total  \
# 0         Mar       1968  Central Asia              1           1
# ...

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9073 entries, 0 to 9072
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country          9073 non-null   object
#  1   Customer Name    9073 non-null   object
#  2   Delivery Year    8048 non-null   object
#  3   Engine           9073 non-null   object
#  4   Model Series     9073 non-null   object
#  5   Order Month      9073 non-null   object
#  6   Order Year       9073 non-null   object
#  7   Region           9047 non-null   object
#  8   Delivery Total   9073 non-null   object
#  9   Order Total      9073 non-null   object
#  10  Unfilled Orders  338 non-null    object
# dtypes: object(11)
# memory usage: 779.8+ KB

# %%
datos.isnull()
# Out:
#       Country  Customer Name  Delivery Year   Engine  Model Series  \
# 0       False          False           False   False         False
# 1       False          False           False   False         False
# 2       False          False           False   False         False
# 3       False          False            True   False         False
# 4       False          False           False   False         False
# ...       ...            ...             ...     ...           ...
# 9068    False          False           False   False         False
# 9069    False          False           False   False         False
# 9070    False          False           False   False         False
# 9071    False          False           False   False         False
# 9072    False          False           False   False         False
#
#       Order Month  Order Year  Region  Delivery Total  Order Total  \
# 0           False       False   False           False        False
# ...

# %%
datos[datos['Unfilled Orders'].isnull()]
# Out:
#           Country           Customer Name Delivery Year  Engine Model Series  \
# 0     Afghanistan  Ariana Afghan Airlines           1968     PW          727
# 1     Afghanistan  Ariana Afghan Airlines           1970     PW          727
# 2     Afghanistan  Ariana Afghan Airlines           1979     GE        DC-10
# 3     Afghanistan  Ariana Afghan Airlines            NaN     CF      737-700
# 4         Algeria             Air Algerie           1974     PW          727
# ...           ...                     ...            ...    ...          ...
# 9067       Zambia          Zambia Airways           1984     GE        DC-10
# 9068     Zimbabwe            Air Zimbabwe           1987     PW      737-200
# 9069     Zimbabwe            Air Zimbabwe           1990     PW    767-200ER
# 9070     Zimbabwe            Air Zimbabwe           1989     PW    767-200ER
# 9071     Zimbabwe            Air Zimbabwe           1986     PW      737-200
#
# ...

# %%
A = datos.shape[0]
datos.dropna(subset = ['Unfilled Orders'], inplace=True)
B = datos.shape[0]
A - B
# Out:
# 0

# %%
datos[datos['Unfilled Orders'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Country, Customer Name, Delivery Year , Engine, Model Series, Order Month, Order Year, Region, Delivery Total, Order Total, Unfilled Orders]
# Index: []

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 338 entries, 71 to 9072
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country          338 non-null    object
#  1   Customer Name    338 non-null    object
#  2   Delivery Year    1 non-null      object
#  3   Engine           338 non-null    object
#  4   Model Series     338 non-null    object
#  5   Order Month      338 non-null    object
#  6   Order Year       338 non-null    object
#  7   Region           338 non-null    object
#  8   Delivery Total   338 non-null    object
#  9   Order Total      338 non-null    object
#  10  Unfilled Orders  338 non-null    object
# dtypes: object(11)
# memory usage: 31.7+ KB

# %%
datos[datos['Delivery Year '].isnull()]
# Out:
#          Country                Customer Name Delivery Year  Engine  \
# 71     Argentina        Aerolineas Argentinas            NaN     CF
# 152    Australia            BDS Australia P-8            NaN     CF
# 185    Australia               Qantas Airways            NaN     GE
# 290    Australia    Virgin Australia Airlines            NaN     CF
# 363   Azerbaijan       Silk Way West Airlines            NaN     GE
# ...          ...                          ...            ...    ...
# 8866         USA                          UPS            NaN     GE
# 8991         USA  Western Global Airlines Inc            NaN     GE
# 9050     Vietnam               Bamboo Airways            NaN     NS
# 9051     Vietnam                  VietJet Air            NaN     CF
# 9052     Vietnam                  VietJet Air            NaN     CF
#
#      Model Series Order Month Order Year          Region Delivery Total  \
# 71        737 MAX         Sep       2016   South America              0
# ...

# %%
datos = datos.fillna({'Delivery Year ': 'N/A'})

# %%
datos[datos['Delivery Year '].isnull()]
# Out:
# Empty DataFrame
# Columns: [Country, Customer Name, Delivery Year , Engine, Model Series, Order Month, Order Year, Region, Delivery Total, Order Total, Unfilled Orders]
# Index: []

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 338 entries, 71 to 9072
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country          338 non-null    object
#  1   Customer Name    338 non-null    object
#  2   Delivery Year    338 non-null    object
#  3   Engine           338 non-null    object
#  4   Model Series     338 non-null    object
#  5   Order Month      338 non-null    object
#  6   Order Year       338 non-null    object
#  7   Region           338 non-null    object
#  8   Delivery Total   338 non-null    object
#  9   Order Total      338 non-null    object
#  10  Unfilled Orders  338 non-null    object
# dtypes: object(11)
# memory usage: 31.7+ KB

# %%
datos.to_csv('Boeing_limpio.csv', sep=';', index = False)
